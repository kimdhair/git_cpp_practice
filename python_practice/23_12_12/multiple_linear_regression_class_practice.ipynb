# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# 데이터셋
X = torch.FloatTensor( [[ 7.71011738e-01, -3.13508197e-01,  5.42352572e-01],
                        [-1.85861239e+00,  2.16116006e-01,  5.08396243e-01],
                        [ 5.39058321e-01, -1.11792545e+00,  4.15393930e-02],
                        [-6.37655012e-01, -2.36184031e-01, -3.38821966e-01],
                        [-8.78107893e-01,  9.02525097e-03, -7.47870949e-01],
                        [-9.88779049e-01,  2.56570452e-01, -1.56434170e-01],
                        [-1.53495196e-01, -1.42121723e+00, -1.18761229e+00],
                        [-6.34679305e-01,  1.27837923e+00,  4.33496330e-01],
                        [-7.44707629e-02, -3.75669423e-01, -3.81092518e-01],
                        [ 9.76147160e-06, -8.44213704e-01,  5.01857207e-01],
                        [ 2.29220801e+00,  5.51454045e-01, -9.09007615e-01],
                        [-8.41747366e-01, -1.79343559e+00,  1.64027081e+00],
                        [ 4.79705919e-02,  6.11340780e-01, -3.35677339e-01],
                        [ 1.17500122e+00, -1.91304965e-02, -5.96159700e-01],
                        [-1.05795222e+00, -1.24528809e+00,  5.02881417e-01],
                        [-2.43476758e+00,  2.23136679e+00, -2.69056960e-01],
                        [ 1.35963386e+00,  3.70444537e-01,  1.12726505e-01],
                        [ 1.00036589e+00,  8.77102184e-02, -8.29135289e-01],
                        [-2.13619610e+00, -5.62668272e-02, -4.16757847e-01],
                        [ 1.46767801e+00,  1.73118467e+00, -1.86809065e+00]])
Y = torch.FloatTensor([[  96.68704955],
                       [-158.98008532],
                       [  54.49974683],
                       [ -71.2832092 ],
                       [-109.68370597],
                       [ -96.20277494],
                       [ -61.52618908],
                       [ -38.24501686],
                       [ -19.32846993],
                       [  16.24620599],
                       [ 198.60935931],
                       [ -31.37236913],
                       [  -0.41438801],
                       [  97.7887465 ],
                       [ -88.92656277],
                       [-234.84110943],
                       [ 140.94339104],
                       [  72.84533909],
                       [-220.9413211 ],
                       [  90.02679734]])


# 다중 선형 회귀 클래스
class MultiLinearRegression(nn.Module):
    def __init__(self):
        super(MultiLinearRegression, self).__init__()
        self.linear = nn.Linear(3, 1)

    def forward(self, x):
        return self.linear(x)


model = MultiLinearRegression()

# 손실 함수와 옵티마이저
loss_fn = nn.MSELoss()  # 평균 제곱 오차
optimizer = optim.SGD(model.parameters(), lr=1e-2)

# 학습
epochs = 2000
for epoch in range(epochs + 1):
    prediction = model(X)

    loss = loss_fn(prediction, Y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 100 ==0:
      w1,w2,w3=model.linear.weight.squeeze().detach().numpy()
      b=model.linear.bias.squeeze().detach().numpy()
      print('Epoch {:4d}/{} W1: {:.4f} W2: {:.4f} W3: {:.4f} Bias: {:.3f} Cost: {:.6f}'.format(
          epoch, epochs, w1, w2, w3, b, loss.item()
      ))

# 예측
model.eval()
x_test = torch.tensor([[1, 2, 3]], dtype=torch.float32)
y_test = model(x_test)
print(f"예측 값: {y_test.squeeze().detach()}")
# Out:
# Epoch    0/2000 W1: 3.3494 W2: 0.4329 W3: -0.2276 Bias: 0.097 Cost: 13116.534180
# Epoch  100/2000 W1: 87.3620 W2: -4.2999 W3: 9.3700 Bias: -5.325 Cost: 303.630127
# Epoch  200/2000 W1: 93.8340 W2: -1.2969 W3: 21.0736 Bias: -1.461 Cost: 83.634109
# Epoch  300/2000 W1: 95.8117 W2: 1.3140 W3: 27.4254 Bias: 0.742 Cost: 25.435266
# Epoch  400/2000 W1: 96.8129 W2: 2.8614 W3: 30.8672 Bias: 1.910 Cost: 8.164827
# Epoch  500/2000 W1: 97.3534 W2: 3.7206 W3: 32.7422 Bias: 2.540 Cost: 3.025637
# Epoch  600/2000 W1: 97.6477 W2: 4.1912 W3: 33.7648 Bias: 2.882 Cost: 1.496175
# Epoch  700/2000 W1: 97.8082 W2: 4.4482 W3: 34.3226 Bias: 3.068 Cost: 1.040995
# Epoch  800/2000 W1: 97.8957 W2: 4.5884 W3: 34.6269 Bias: 3.170 Cost: 0.905530
# Epoch  900/2000 W1: 97.9435 W2: 4.6649 W3: 34.7930 Bias: 3.226 Cost: 0.865213
# Epoch 1000/2000 W1: 97.9695 W2: 4.7066 W3: 34.8835 Bias: 3.256 Cost: 0.853212
# Epoch 1100/2000 W1: 97.9837 W2: 4.7294 W3: 34.9329 Bias: 3.272 Cost: 0.849642
# Epoch 1200/2000 W1: 97.9915 W2: 4.7418 W3: 34.9599 Bias: 3.281 Cost: 0.848580
# Epoch 1300/2000 W1: 97.9957 W2: 4.7486 W3: 34.9746 Bias: 3.286 Cost: 0.848263
# Epoch 1400/2000 W1: 97.9979 W2: 4.7523 W3: 34.9826 Bias: 3.289 Cost: 0.848166
# Epoch 1500/2000 W1: 97.9992 W2: 4.7543 W3: 34.9870 Bias: 3.290 Cost: 0.848140
# Epoch 1600/2000 W1: 98.0000 W2: 4.7554 W3: 34.9894 Bias: 3.291 Cost: 0.848131
# Epoch 1700/2000 W1: 98.0003 W2: 4.7560 W3: 34.9907 Bias: 3.292 Cost: 0.848129
# Epoch 1800/2000 W1: 98.0004 W2: 4.7563 W3: 34.9913 Bias: 3.292 Cost: 0.848131
# Epoch 1900/2000 W1: 98.0005 W2: 4.7565 W3: 34.9917 Bias: 3.292 Cost: 0.848129
# Epoch 2000/2000 W1: 98.0006 W2: 4.7566 W3: 34.9919 Bias: 3.292 Cost: 0.848127
# 예측 값: 215.78146362304688
