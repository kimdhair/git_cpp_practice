# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font',family='Malgun Gothic')

# %%
subway_filepath='./서울시 지하철 호선별 역별 시간대별 승하차 인원 정보.csv'
subway_file=pd.read_csv(subway_filepath, index_col='사용월',encoding='CP949')
subway_data=subway_file.iloc[:,:-1]
subway_file.head()
# Out:
#         호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 사용월
# 202310  1호선  동대문           688            23         11493          2221
# 202310  1호선  동묘앞           208             1          3065          1120
# 202310  1호선  서울역           700            16          8826          9093
# 202310  1호선   시청            60             1          2408          5020
# 202310  1호선  신설동           388            18          9245          2315
#
#         06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  07시-08시 하차인원  ...  \
# 사용월                                                             ...
# 202310          9618          6755         14951         12017  ...
# 202310          3652          4528          7542          9281  ...
# 202310         13369         60044         42194        111515  ...
# 202310          4325         26689          8093         70011  ...
# 202310          9988          8178         21304         22493  ...
#
# ...

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=subway_data)
# Out:
# <Axes: xlabel='사용월'>
