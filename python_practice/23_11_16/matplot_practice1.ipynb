# %%
import matplotlib.pyplot as plt

plt.plot([0,1,2,3,4])

# %%
plt.plot([1,2,3,4,6])
plt.axis([-1,5,0,7])
# Out:
# (-1.0, 5.0, 0.0, 7.0)

# %%
import numpy as np

x=np.arange(3)

plt.bar(x,[100,400,900],color=['r','g','b'],width=0.5)
plt.xticks(x,['2018','2019','2020'])
plt.show()

# %%
y=np.arange(3)

plt.barh(y,[100,150,400],height=0.5)
plt.yticks(y,['2018','2019','2020'])
# Out:
# ([<matplotlib.axis.YTick at 0x2255bad7390>,
#   <matplotlib.axis.YTick at 0x2255cbee250>,
#   <matplotlib.axis.YTick at 0x2255bad5e10>],
#  [Text(0, 0, '2018'), Text(0, 1, '2019'), Text(0, 2, '2020')])

# %%
n = 50
x = np.random.rand(n)
y = np.random.rand(n)

area = (30 * np.random.rand(n)) ** 2
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors, cmap="Spectral", alpha=0.5,edgecolors='r')
plt.show()

# %%
ratio = [34,32,16,18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
wedgeprops = { 'width' : 0.7, 'edgecolor':'k', 'linewidth':1}

plt.pie(ratio, labels=labels, autopct='%.1f%%', explode=[0, 0.1, 0, 0.1], colors=['red', 'yellow', 'green', 'purple'], wedgeprops=wedgeprops)
# Out:
# ([<matplotlib.patches.Wedge at 0x22564c00690>,
#   <matplotlib.patches.Wedge at 0x22564c04910>,
#   <matplotlib.patches.Wedge at 0x22564c05f50>,
#   <matplotlib.patches.Wedge at 0x22564c05390>],
#  [Text(0.5299290306818474, 0.9639373540021144, 'Apple'),
#   Text(-1.2000000000000002, 1.469576158976824e-16, 'Banana'),
#   Text(-0.06906960848527934, -1.0978293989430645, 'Melon'),
#   Text(1.0131934961541131, -0.6429921767416812, 'Grapes')],
#  [Text(0.28905219855373493, 0.5257840112738805, '34.0%'),
#   Text(-0.7, 8.572527594031472e-17, '32.0%'),
#   Text(-0.037674331901061446, -0.598816035787126, '16.0%'),
#   Text(0.5910295394232326, -0.3750787697659807, '18.0%')])

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales_2019 = [100,120,140,110,130,150,160,170,180,200,190,210]
sales_2020 = [90,110,130,120,140,160,170,160,150,180,200,190]

plt.plot(months,sales_2019,label='2019')
plt.plot(months,sales_2020,label='2020')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.title('Monthly Sales Comparison (2019-2020)')
plt.legend(loc='best',ncol=1,fontsize=13,frameon=True)

# %%
categories = ['Category 1','Category 2','Category 3','Category 4','Category 5']
data = [20, 35, 15, 27, 45]
plt.ylim(0,50)
plt.bar(categories,data)
plt.xticks(rotation=45)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart')
plt.grid()

# %%
labels = ['Apple', 'Banana', 'Mango', 'Blueberry']
sizes = [15, 30, 45, 10]
wedgeprops={'width':1}
explode=[0,0.1,0,0]

plt.pie(sizes,labels=labels,autopct='%.1f%%',explode=explode,wedgeprops=wedgeprops,startangle=90,shadow=True)
plt.show()

# %%
x=np.linspace(0,10,100)
sin=np.sin(x)
cos=np.cos(x)
plt.plot(x,sin,label='sin(x)',color='b')
plt.plot(x,cos,label='cos(x)',color='r')
plt.title('Sine and Cosine Functions')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()
plt.legend()
